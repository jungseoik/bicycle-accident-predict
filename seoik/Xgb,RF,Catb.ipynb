# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from ANN.get import get, prepro


X_trn, y_trn, X_tst, y_tst = get('data/f5.csv')
# 데이터와 타겟을 X, y로 가정합니다.
X_train, X_test, y_train, y_test = X_trn, X_tst, y_trn, y_tst

# 모델을 딕셔너리 형태로 정의합니다.
models = {
    'xgboost': XGBClassifier(),
    'catboost': CatBoostClassifier(verbose=0),
    'random_forest': RandomForestClassifier()
}

# 각 모델의 파라미터를 딕셔너리 형태로 정의합니다.
params = {
    'xgboost': {'model__n_estimators': [50, 100, 200], 'model__learning_rate': [0.01, 0.1, 0.2], 'model__max_depth': [3, 5, 7, 9]},
    'catboost': {'model__iterations': [50, 100, 200], 'model__learning_rate': [0.01, 0.1, 0.2], 'model__depth': [3, 5, 7, 9]},
    'random_forest': {'model__n_estimators': [50, 100, 200], 'model__max_depth': [None, 5, 10], 'model__min_samples_split': [2, 5, 10]}
}

# 성능 지표를 딕셔너리 형태로 정의합니다.
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, average='macro'),
    'recall': make_scorer(recall_score, average='macro'),
    'f1': make_scorer(f1_score, average='macro')
}

for name, model in models.items():
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])

    clf = GridSearchCV(pipe, params[name], cv=5, scoring=scoring, refit='f1')
    clf.fit(X_train, y_train)

    print(f"Best parameters for {name}: {clf.best_params_}")
    print(f"Best score for {name}: {clf.best_score_}")
    for scorer in scoring:
        print(f"{scorer}: {clf.cv_results_['mean_test_'+scorer]}")
# Out:
# Best parameters for xgboost: {'model__learning_rate': 0.1, 'model__max_depth': 9, 'model__n_estimators': 200}
# Best score for xgboost: 0.7851960954870625
# accuracy: [0.70637739 0.72603902 0.74249725 0.73469476 0.75327132 0.77926285
#  0.77050423 0.7771185  0.79078598 0.78587693 0.79081172 0.79900193
#  0.7820531  0.79564327 0.8028001  0.7984078  0.80398855 0.80695976
#  0.80256746 0.80497035 0.80719226 0.80605533 0.80708881 0.80768314
#  0.79484233 0.80378186 0.80677888 0.80236091 0.80590051 0.80497041
#  0.80553879 0.80571963 0.80525461 0.80677883 0.80652055 0.80437619]
# precision: [0.70001267 0.72452683 0.75325036 0.73766945 0.76386061 0.79892674
#  0.78739913 0.79494298 0.81649813 0.80916503 0.81477643 0.82711413
#  0.80597677 0.83006283 0.83831551 0.82923434 0.8414903  0.8390314
#  0.83933706 0.83921153 0.84094502 0.83692779 0.83969454 0.83799855
#  0.83219347 0.84698765 0.84312533 0.84085019 0.83080719 0.83308351
#  0.8354065  0.83528986 0.83200956 0.83753831 0.83307587 0.8298905 ]
# recall: [0.70637243 0.72602902 0.74248064 0.73468019 0.75325277 0.77924197
#  0.77048427 0.77709743 0.79076391 0.78585632 0.79079061 0.7989801
#  0.78203278 0.79562121 0.80277784 0.79838511 0.80396572 0.80693694
#  0.8025449  0.80494755 0.8071692  0.8060328  0.80706586 0.80766009
#  0.79482019 0.80375956 0.80675646 0.80233817 0.80587759 0.80494744
#  0.80551605 0.80569678 0.80523176 0.8067559  0.8064977  0.80435291]
# f1: [0.68961721 0.71071495 0.72150842 0.71628484 0.72983117 0.75399664
#  0.74960296 0.75348464 0.76461892 0.76340225 0.76775859 0.77502018
#  0.75775588 0.76902125 0.77550058 0.77077101 0.77684019 0.78067474
#  0.77623633 0.77929476 0.78294359 0.78157249 0.783352   0.7851961
#  0.76812413 0.77678683 0.78065966 0.77532107 0.77966945 0.78086067
#  0.78027888 0.78230531 0.78376024 0.78300756 0.78426337 0.78291152]
# Best parameters for catboost: {'model__depth': 9, 'model__iterations': 200, 'model__learning_rate': 0.2}
# Best score for catboost: 0.7812103536621066
# accuracy: [0.70640354 0.77874593 0.78995926 0.71513606 0.79158693 0.79835616
#  0.74203201 0.79884706 0.8027484  0.72965651 0.79187105 0.79822693
#  0.75236683 0.79938958 0.80277418 0.77231267 0.80326511 0.80491868
#  0.75985957 0.79657334 0.80168904 0.77228697 0.80308418 0.80416935
#  0.78463687 0.80517701 0.80636546 0.76854062 0.79980286 0.80158568
#  0.78076128 0.80349753 0.80373015 0.79047589 0.80484107 0.80515123]
# precision: [0.70403929 0.79724717 0.81689114 0.71453935 0.81922055 0.83298173
#  0.74834648 0.83892273 0.83594064 0.73560079 0.81867559 0.83351844
#  0.7647256  0.83443512 0.83971876 0.7908697  0.83765581 0.83752075
#  0.77269832 0.82590582 0.83422502 0.78965548 0.83727344 0.83545743
#  0.80586353 0.83887701 0.84238161 0.78334104 0.83356964 0.83337161
#  0.80129813 0.83698784 0.83570265 0.81580307 0.83917621 0.83409708]
# recall: [0.70639072 0.77872635 0.78993798 0.71512316 0.79156579 0.79833402
#  0.74201779 0.79882494 0.80272604 0.72963996 0.79184985 0.79820468
#  0.75234953 0.79936731 0.80275172 0.77229411 0.8032425  0.80489585
#  0.75984175 0.79655147 0.80166651 0.77226809 0.80306176 0.80414651
#  0.78461688 0.80515454 0.80634262 0.7685216  0.7997808  0.80156308
#  0.78074174 0.80347486 0.80370714 0.79045522 0.8048181  0.80512819]
# f1: [0.68974466 0.75672838 0.76326793 0.69943007 0.76481069 0.77038584
#  0.72537538 0.77066184 0.77510953 0.71039898 0.76550794 0.77056031
#  0.73220986 0.77180623 0.77558562 0.75032781 0.77579874 0.77798032
#  0.73862234 0.76929419 0.7747002  0.74880315 0.77563039 0.77755578
#  0.75924938 0.77815324 0.78081238 0.74638479 0.77343931 0.77512531
#  0.7574127  0.77704517 0.77826095 0.76440316 0.77910783 0.78121035]
# Best parameters for random_forest: {'model__max_depth': None, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# Best score for random_forest: 0.7906624129312363
# accuracy: [0.81217849 0.81494295 0.81517555 0.81186846 0.81460709 0.81551142
#  0.81093845 0.81292785 0.81393547 0.77078829 0.77249364 0.7723385
#  0.76784294 0.76719723 0.77166682 0.76440667 0.76866976 0.76978088
#  0.79517808 0.79404131 0.79502307 0.79238777 0.79758083 0.79685746
#  0.79667648 0.79628902 0.79636653]
# precision: [0.84385587 0.85003155 0.84992949 0.84514665 0.85517162 0.85506364
#  0.84641242 0.85295499 0.85681495 0.78544364 0.79064073 0.79265319
#  0.7828783  0.78350795 0.78913099 0.77965813 0.78639098 0.78564378
#  0.81726145 0.8177729  0.82528988 0.81843984 0.82663477 0.82563451
#  0.82534376 0.82421996 0.82711221]
# recall: [0.81215565 0.81491994 0.81515258 0.81184551 0.81458431 0.81548835
#  0.81091557 0.8129051  0.81391239 0.7707712  0.77247575 0.77231963
#  0.76782465 0.76717828 0.77164784 0.76439091 0.76865092 0.76976206
#  0.79515741 0.79402069 0.79500183 0.79236633 0.79755981 0.79683627
#  0.79665523 0.79626767 0.79634512]
# f1: [0.78882016 0.79066241 0.79044206 0.78715135 0.78947611 0.78970834
#  0.78477285 0.78659928 0.78682327 0.75214573 0.75083245 0.75067893
#  0.74854324 0.74439571 0.75071777 0.74391741 0.74727542 0.74733176
#  0.77110666 0.76919919 0.76925039 0.76652262 0.77332274 0.77144228
#  0.77293054 0.7719115  0.77101444]

# %%
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import pandas as pd
X_trn, y_trn, X_tst, y_tst = get('data/f5.csv')
X_train, X_test, y_train, y_test = X_trn, X_tst, y_trn, y_tst
# 모델 생성
xgb_model = XGBClassifier(learning_rate=0.1, max_depth=9, n_estimators=200)
cat_model = CatBoostClassifier(depth=9, iterations=200, learning_rate=0.2)
rf_model = RandomForestClassifier(max_depth=None, min_samples_split=2, n_estimators=200)

# 데이터와 레이블로 분리되어 있는 X_train, y_train, X_test, y_test를 사용한다고 가정합니다.

# 모델 학습
xgb_model.fit(X_train, y_train)
cat_model.fit(X_train, y_train)
rf_model.fit(X_train, y_train)

# 예측
models = [xgb_model, cat_model, rf_model]
model_names = ['XGBoost', 'CatBoost', 'RandomForest']
results = []

for model, name in zip(models, model_names):
    pred = model.predict(X_test)
    
    # 성능 지표 계산
    accuracy = accuracy_score(y_test, pred)
    precision_per_class = precision_score(y_test, pred, average=None)
    recall_per_class = recall_score(y_test, pred, average=None)
    f1_per_class = f1_score(y_test, pred, average=None)
    confusion_matrix1 = multilabel_confusion_matrix(y_test, pred)
    confusion_matrix2 = confusion_matrix(y_test, pred)

    # 결과 DataFrame 생성
    metrics_df = pd.DataFrame({
        'Model': [name],
        'Accuracy': [accuracy],
        'Precision (Class 0)': [precision_per_class[0]],
        'Precision (Class 1)': [precision_per_class[1]],
        'Precision (Class 2)': [precision_per_class[2]],
        'Recall (Class 0)': [recall_per_class[0]],
        'Recall (Class 1)': [recall_per_class[1]],
        'Recall (Class 2)': [recall_per_class[2]],
        'F1 Score (Class 0)': [f1_per_class[0]],
        'F1 Score (Class 1)': [f1_per_class[1]],
        'F1 Score (Class 2)': [f1_per_class[2]],
        'Label Confusion Matrix': [confusion_matrix1],
        'Confusion Matrix': [confusion_matrix2]
    })
    
    # 결과 저장
    results.append(metrics_df)

# 결과를 하나의 DataFrame으로 결합
final_df = pd.concat(results, ignore_index=True)
final_df.head()
# Out:
# 0:	learn: 0.9339140	total: 36.3ms	remaining: 7.21s
# 1:	learn: 0.8158593	total: 68.5ms	remaining: 6.78s
# 2:	learn: 0.7338509	total: 104ms	remaining: 6.85s
# 3:	learn: 0.6794822	total: 137ms	remaining: 6.72s
# 4:	learn: 0.6355502	total: 172ms	remaining: 6.71s
# 5:	learn: 0.5997385	total: 204ms	remaining: 6.61s
# 6:	learn: 0.5738618	total: 244ms	remaining: 6.72s
# 7:	learn: 0.5538043	total: 280ms	remaining: 6.73s
# 8:	learn: 0.5359052	total: 317ms	remaining: 6.72s
# 9:	learn: 0.5180003	total: 352ms	remaining: 6.69s
# 10:	learn: 0.5061613	total: 387ms	remaining: 6.65s
# 11:	learn: 0.4970668	total: 423ms	remaining: 6.63s
# 12:	learn: 0.4880698	total: 458ms	remaining: 6.58s
# 13:	learn: 0.4816580	total: 493ms	remaining: 6.55s
# 14:	learn: 0.4741605	total: 526ms	remaining: 6.49s
# 15:	learn: 0.4696764	total: 561ms	remaining: 6.45s
# 16:	learn: 0.4664391	total: 597ms	remaining: 6.43s
# 17:	learn: 0.4621011	total: 631ms	remaining: 6.38s
# 18:	learn: 0.4599703	total: 664ms	remaining: 6.33s
# 19:	learn: 0.4569246	total: 699ms	remaining: 6.29s
# 20:	learn: 0.4541643	total: 737ms	remaining: 6.28s
# 21:	learn: 0.4506454	total: 769ms	remaining: 6.22s
# 22:	learn: 0.4487576	total: 803ms	remaining: 6.18s
# 23:	learn: 0.4464703	total: 839ms	remaining: 6.15s
# 24:	learn: 0.4421635	total: 871ms	remaining: 6.1s
# 25:	learn: 0.4395828	total: 905ms	remaining: 6.06s
# 26:	learn: 0.4372556	total: 941ms	remaining: 6.03s
# 27:	learn: 0.4347495	total: 981ms	remaining: 6.03s
# 28:	learn: 0.4332244	total: 1.01s	remaining: 5.97s
# 29:	learn: 0.4313171	total: 1.05s	remaining: 5.95s
# 30:	learn: 0.4297438	total: 1.08s	remaining: 5.91s
# 31:	learn: 0.4282933	total: 1.12s	remaining: 5.87s
# 32:	learn: 0.4263624	total: 1.15s	remaining: 5.84s
# 33:	learn: 0.4247415	total: 1.19s	remaining: 5.81s
# 34:	learn: 0.4228377	total: 1.23s	remaining: 5.78s
# 35:	learn: 0.4216852	total: 1.26s	remaining: 5.74s
# 36:	learn: 0.4203665	total: 1.29s	remaining: 5.69s
# 37:	learn: 0.4185799	total: 1.33s	remaining: 5.65s
# 38:	learn: 0.4174964	total: 1.36s	remaining: 5.63s
# 39:	learn: 0.4159783	total: 1.4s	remaining: 5.58s
# 40:	learn: 0.4142909	total: 1.43s	remaining: 5.55s
# 41:	learn: 0.4130140	total: 1.47s	remaining: 5.52s
# 42:	learn: 0.4121124	total: 1.5s	remaining: 5.48s
# 43:	learn: 0.4107525	total: 1.53s	remaining: 5.43s
# 44:	learn: 0.4090006	total: 1.56s	remaining: 5.39s
# 45:	learn: 0.4079278	total: 1.6s	remaining: 5.36s
# 46:	learn: 0.4067633	total: 1.63s	remaining: 5.32s
# 47:	learn: 0.4056310	total: 1.67s	remaining: 5.28s
# 48:	learn: 0.4044784	total: 1.71s	remaining: 5.27s
# 49:	learn: 0.4036458	total: 1.74s	remaining: 5.23s
# 50:	learn: 0.4028865	total: 1.78s	remaining: 5.19s
# 51:	learn: 0.4017994	total: 1.81s	remaining: 5.17s
# 52:	learn: 0.4010758	total: 1.85s	remaining: 5.14s
# 53:	learn: 0.3996827	total: 1.89s	remaining: 5.1s
# 54:	learn: 0.3984332	total: 1.92s	remaining: 5.07s
# 55:	learn: 0.3968437	total: 1.96s	remaining: 5.04s
# 56:	learn: 0.3955991	total: 1.99s	remaining: 5s
# 57:	learn: 0.3945317	total: 2.03s	remaining: 4.96s
# 58:	learn: 0.3940968	total: 2.06s	remaining: 4.92s
# 59:	learn: 0.3929070	total: 2.09s	remaining: 4.88s
# 60:	learn: 0.3918439	total: 2.13s	remaining: 4.85s
# 61:	learn: 0.3910062	total: 2.16s	remaining: 4.82s
# 62:	learn: 0.3904235	total: 2.2s	remaining: 4.79s
# 63:	learn: 0.3893438	total: 2.23s	remaining: 4.75s
# 64:	learn: 0.3884870	total: 2.27s	remaining: 4.72s
# 65:	learn: 0.3872116	total: 2.31s	remaining: 4.68s
# 66:	learn: 0.3860278	total: 2.34s	remaining: 4.64s
# 67:	learn: 0.3848915	total: 2.37s	remaining: 4.6s
# 68:	learn: 0.3841370	total: 2.41s	remaining: 4.57s
# 69:	learn: 0.3833682	total: 2.44s	remaining: 4.54s
# 70:	learn: 0.3826066	total: 2.48s	remaining: 4.5s
# 71:	learn: 0.3813822	total: 2.51s	remaining: 4.46s
# 72:	learn: 0.3806172	total: 2.54s	remaining: 4.42s
# 73:	learn: 0.3797059	total: 2.58s	remaining: 4.39s
# 74:	learn: 0.3786425	total: 2.61s	remaining: 4.35s
# 75:	learn: 0.3778357	total: 2.64s	remaining: 4.31s
# 76:	learn: 0.3770255	total: 2.68s	remaining: 4.27s
# 77:	learn: 0.3764025	total: 2.71s	remaining: 4.25s
# 78:	learn: 0.3744965	total: 2.75s	remaining: 4.21s
# 79:	learn: 0.3734098	total: 2.78s	remaining: 4.17s
# 80:	learn: 0.3728803	total: 2.81s	remaining: 4.14s
# 81:	learn: 0.3723366	total: 2.85s	remaining: 4.1s
# 82:	learn: 0.3712963	total: 2.88s	remaining: 4.07s
# 83:	learn: 0.3704492	total: 2.92s	remaining: 4.03s
# 84:	learn: 0.3694085	total: 2.95s	remaining: 4s
# 85:	learn: 0.3687996	total: 2.99s	remaining: 3.97s
# 86:	learn: 0.3681463	total: 3.03s	remaining: 3.93s
# 87:	learn: 0.3671588	total: 3.06s	remaining: 3.9s
# 88:	learn: 0.3665803	total: 3.1s	remaining: 3.87s
# 89:	learn: 0.3658774	total: 3.13s	remaining: 3.83s
# 90:	learn: 0.3646199	total: 3.17s	remaining: 3.79s
# 91:	learn: 0.3636697	total: 3.2s	remaining: 3.76s
# 92:	learn: 0.3626597	total: 3.24s	remaining: 3.73s
# 93:	learn: 0.3618358	total: 3.27s	remaining: 3.69s
# 94:	learn: 0.3615073	total: 3.31s	remaining: 3.66s
# 95:	learn: 0.3603706	total: 3.35s	remaining: 3.63s
# 96:	learn: 0.3592554	total: 3.39s	remaining: 3.6s
# 97:	learn: 0.3582392	total: 3.42s	remaining: 3.56s
# 98:	learn: 0.3575784	total: 3.46s	remaining: 3.53s
# 99:	learn: 0.3568201	total: 3.5s	remaining: 3.5s
# 100:	learn: 0.3558533	total: 3.53s	remaining: 3.46s
# 101:	learn: 0.3547556	total: 3.57s	remaining: 3.43s
# 102:	learn: 0.3542428	total: 3.6s	remaining: 3.4s
# 103:	learn: 0.3530049	total: 3.64s	remaining: 3.36s
# 104:	learn: 0.3525801	total: 3.68s	remaining: 3.33s
# 105:	learn: 0.3518248	total: 3.72s	remaining: 3.29s
# 106:	learn: 0.3513341	total: 3.75s	remaining: 3.26s
# 107:	learn: 0.3507729	total: 3.78s	remaining: 3.22s
# 108:	learn: 0.3497855	total: 3.82s	remaining: 3.19s
# 109:	learn: 0.3491880	total: 3.86s	remaining: 3.16s
# 110:	learn: 0.3484735	total: 3.9s	remaining: 3.12s
# 111:	learn: 0.3466800	total: 3.93s	remaining: 3.09s
# 112:	learn: 0.3462958	total: 3.97s	remaining: 3.06s
# 113:	learn: 0.3455272	total: 4.01s	remaining: 3.02s
# 114:	learn: 0.3448615	total: 4.04s	remaining: 2.99s
# 115:	learn: 0.3439045	total: 4.07s	remaining: 2.95s
# 116:	learn: 0.3432501	total: 4.12s	remaining: 2.92s
# 117:	learn: 0.3426231	total: 4.16s	remaining: 2.89s
# 118:	learn: 0.3421476	total: 4.2s	remaining: 2.86s
# 119:	learn: 0.3416064	total: 4.24s	remaining: 2.82s
# 120:	learn: 0.3409367	total: 4.27s	remaining: 2.79s
# 121:	learn: 0.3398362	total: 4.31s	remaining: 2.75s
# 122:	learn: 0.3390419	total: 4.34s	remaining: 2.72s
# 123:	learn: 0.3382834	total: 4.38s	remaining: 2.68s
# 124:	learn: 0.3378928	total: 4.41s	remaining: 2.65s
# 125:	learn: 0.3373537	total: 4.45s	remaining: 2.61s
# 126:	learn: 0.3366696	total: 4.49s	remaining: 2.58s
# 127:	learn: 0.3363574	total: 4.52s	remaining: 2.54s
# 128:	learn: 0.3354971	total: 4.56s	remaining: 2.51s
# 129:	learn: 0.3346655	total: 4.59s	remaining: 2.47s
# 130:	learn: 0.3341694	total: 4.63s	remaining: 2.44s
# 131:	learn: 0.3335658	total: 4.67s	remaining: 2.4s
# 132:	learn: 0.3327561	total: 4.7s	remaining: 2.37s
# 133:	learn: 0.3320711	total: 4.75s	remaining: 2.34s
# 134:	learn: 0.3313595	total: 4.78s	remaining: 2.3s
# 135:	learn: 0.3307026	total: 4.82s	remaining: 2.27s
# 136:	learn: 0.3299060	total: 4.86s	remaining: 2.23s
# 137:	learn: 0.3293441	total: 4.89s	remaining: 2.2s
# 138:	learn: 0.3286941	total: 4.92s	remaining: 2.16s
# 139:	learn: 0.3283068	total: 4.96s	remaining: 2.13s
# 140:	learn: 0.3272768	total: 5s	remaining: 2.09s
# 141:	learn: 0.3260893	total: 5.07s	remaining: 2.07s
# 142:	learn: 0.3254593	total: 5.1s	remaining: 2.03s
# 143:	learn: 0.3250375	total: 5.14s	remaining: 2s
# 144:	learn: 0.3241979	total: 5.17s	remaining: 1.96s
# 145:	learn: 0.3232288	total: 5.21s	remaining: 1.93s
# 146:	learn: 0.3226319	total: 5.25s	remaining: 1.89s
# 147:	learn: 0.3219844	total: 5.28s	remaining: 1.85s
# 148:	learn: 0.3213861	total: 5.31s	remaining: 1.82s
# 149:	learn: 0.3207842	total: 5.34s	remaining: 1.78s
# 150:	learn: 0.3200698	total: 5.38s	remaining: 1.75s
# 151:	learn: 0.3194101	total: 5.41s	remaining: 1.71s
# 152:	learn: 0.3186278	total: 5.45s	remaining: 1.67s
# 153:	learn: 0.3180726	total: 5.49s	remaining: 1.64s
# 154:	learn: 0.3177268	total: 5.52s	remaining: 1.6s
# 155:	learn: 0.3172823	total: 5.56s	remaining: 1.57s
# 156:	learn: 0.3169429	total: 5.59s	remaining: 1.53s
# 157:	learn: 0.3165331	total: 5.63s	remaining: 1.5s
# 158:	learn: 0.3159306	total: 5.67s	remaining: 1.46s
# 159:	learn: 0.3154300	total: 5.7s	remaining: 1.43s
# 160:	learn: 0.3149582	total: 5.74s	remaining: 1.39s
# 161:	learn: 0.3142610	total: 5.78s	remaining: 1.35s
# 162:	learn: 0.3133745	total: 5.81s	remaining: 1.32s
# 163:	learn: 0.3124465	total: 5.85s	remaining: 1.28s
# 164:	learn: 0.3120594	total: 5.88s	remaining: 1.25s
# 165:	learn: 0.3115758	total: 5.92s	remaining: 1.21s
# 166:	learn: 0.3109956	total: 5.95s	remaining: 1.18s
# 167:	learn: 0.3104352	total: 5.99s	remaining: 1.14s
# 168:	learn: 0.3096806	total: 6.03s	remaining: 1.1s
# 169:	learn: 0.3090561	total: 6.06s	remaining: 1.07s
# 170:	learn: 0.3082343	total: 6.1s	remaining: 1.03s
# 171:	learn: 0.3074228	total: 6.14s	remaining: 999ms
# 172:	learn: 0.3069331	total: 6.17s	remaining: 963ms
# 173:	learn: 0.3067210	total: 6.21s	remaining: 927ms
# 174:	learn: 0.3060703	total: 6.24s	remaining: 892ms
# 175:	learn: 0.3056044	total: 6.27s	remaining: 856ms
# 176:	learn: 0.3052144	total: 6.31s	remaining: 820ms
# 177:	learn: 0.3047555	total: 6.34s	remaining: 784ms
# 178:	learn: 0.3040610	total: 6.38s	remaining: 749ms
# 179:	learn: 0.3034052	total: 6.42s	remaining: 713ms
# 180:	learn: 0.3025721	total: 6.45s	remaining: 677ms
# 181:	learn: 0.3019793	total: 6.49s	remaining: 642ms
# 182:	learn: 0.3012539	total: 6.52s	remaining: 606ms
# 183:	learn: 0.3009093	total: 6.56s	remaining: 570ms
# 184:	learn: 0.3005200	total: 6.59s	remaining: 535ms
# 185:	learn: 0.2998181	total: 6.63s	remaining: 499ms
# 186:	learn: 0.2994214	total: 6.67s	remaining: 463ms
# 187:	learn: 0.2989719	total: 6.7s	remaining: 428ms
# 188:	learn: 0.2981203	total: 6.74s	remaining: 392ms
# 189:	learn: 0.2974524	total: 6.78s	remaining: 357ms
# 190:	learn: 0.2965775	total: 6.81s	remaining: 321ms
# 191:	learn: 0.2961778	total: 6.84s	remaining: 285ms
# 192:	learn: 0.2954644	total: 6.88s	remaining: 250ms
# 193:	learn: 0.2945474	total: 6.92s	remaining: 214ms
# 194:	learn: 0.2941032	total: 6.97s	remaining: 179ms
# 195:	learn: 0.2938795	total: 7s	remaining: 143ms
# 196:	learn: 0.2933896	total: 7.03s	remaining: 107ms
# 197:	learn: 0.2929938	total: 7.08s	remaining: 71.5ms
# 198:	learn: 0.2922547	total: 7.11s	remaining: 35.7ms
# 199:	learn: 0.2920326	total: 7.15s	remaining: 0us
#           Model  Accuracy  Precision (Class 0)  Precision (Class 1)  \
# 0       XGBoost  0.743210             0.832669             0.731734
# 1      CatBoost  0.747490             0.829871             0.736728
# 2  RandomForest  0.750782             0.823729             0.736041
#
#    Precision (Class 2)  Recall (Class 0)  Recall (Class 1)  Recall (Class 2)  \
# 0             0.360335          0.932515          0.849186          0.118785
# 1             0.396122          0.935862          0.851064          0.131676
# 2             0.393258          0.948689          0.862015          0.096685
#
#    F1 Score (Class 0)  F1 Score (Class 1)  F1 Score (Class 2)  \
# 0            0.879768            0.786097            0.178670
# 1            0.879685            0.789779            0.197650
# 2            0.881804            0.794063            0.155211
#
#                               Label Confusion Matrix  \
# 0  [[[3946, 336], [121, 1672]], [[1884, 995], [48...
# 1  [[[3938, 344], [115, 1678]], [[1907, 972], [47...
# 2  [[[3918, 364], [92, 1701]], [[1891, 988], [441...
#
#                                     Confusion Matrix
# 0  [[1672, 106, 15], [268, 2714, 214], [68, 889, ...
# 1  [[1678, 102, 13], [271, 2720, 205], [73, 870, ...
# 2  [[1701, 88, 4], [283, 2755, 158], [81, 900, 105]]
