# %% [markdown]
# # 2조
#
# # 데이터 SET
# ### 교통사고분석시스템의 자전거 사고 데이터
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png) ![image-4.png](attachment:image-4.png)
#
# # 데이터 형태
#
# ![image-3.png](attachment:image-3.png)

# %%
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Replace 'your_folder_path' with the path to your folder containing CSV files
folder_path = 'data/20-22'
# Replace 'output_combined.csv' with the desired name for your combined CSV file
output_file = 'output_combined.csv'
# Get all CSV files in the folder
csv_files = glob.glob(os.path.join(folder_path, '*.csv'))

combined_data = pd.DataFrame()

for csv_file in csv_files:
    df = pd.read_csv(csv_file,  encoding='cp949')
    combined_data = pd.concat([combined_data, df], ignore_index=True)

# Save the combined data to a new CSV file
combined_data.to_csv(output_file, index=False)

# %%
df = pd.read_csv('output_combined.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32632 entries, 0 to 32631
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        32632 non-null  int64
#  1   사고일시        32632 non-null  object
#  2   요일          32632 non-null  object
#  3   시군구         32632 non-null  object
#  4   사고내용        32632 non-null  object
#  5   사망자수        32632 non-null  int64
#  6   중상자수        32632 non-null  int64
#  7   경상자수        32632 non-null  int64
#  8   부상신고자수      32632 non-null  int64
#  9   사고유형        32632 non-null  object
#  10  법규위반        32632 non-null  object
#  11  노면상태        32632 non-null  object
#  12  기상상태        32632 non-null  object
#  13  도로형태        32632 non-null  object
#  14  가해운전자 차종    32632 non-null  object
#  15  가해운전자 성별    32632 non-null  object
#  16  가해운전자 연령    32632 non-null  object
#  17  가해운전자 상해정도  32632 non-null  object
#  18  피해운전자 차종    31198 non-null  object
#  19  피해운전자 성별    31198 non-null  object
#  20  피해운전자 연령    31198 non-null  object
#  21  피해운전자 상해정도  31198 non-null  object
# dtypes: int64(5), object(17)
# memory usage: 5.5+ MB

# %%
df.head()
# Out:
#                사고번호              사고일시   요일              시군구    사고내용  사망자수  \
# 0  2020010200100362   2020년 1월 2일 17시  목요일  경상북도 포항시 북구 죽도동    경상사고     0
# 1  2020010800100465   2020년 1월 8일 18시  수요일     경상북도 경주시 안강읍    중상사고     0
# 2  2020011000100216  2020년 1월 10일 11시  금요일     경상북도 안동시 운흥동    경상사고     0
# 3  2020011100100222  2020년 1월 11일 12시  토요일     경상북도 안동시 북문동  부상신고사고     0
# 4  2020011300100133  2020년 1월 13일 10시  월요일     경상북도 경산시 중방동    경상사고     0
#
#    중상자수  경상자수  부상신고자수        사고유형  ... 기상상태         도로형태 가해운전자 차종 가해운전자 성별  \
# 0     0     1       0  차대차 - 측면충돌  ...   맑음   교차로 - 교차로안      자전거        남
# 1     1     0       0  차대차 - 측면충돌  ...   맑음     단일로 - 기타      자전거        남
# 2     0     1       0  차대차 - 측면충돌  ...   맑음  교차로 - 교차로부근      자전거        남
# 3     0     0       1  차대차 - 측면충돌  ...   맑음   교차로 - 교차로안      자전거        남
# 4     0     1       0  차대차 - 측면충돌  ...   맑음   교차로 - 교차로안      자전거        여
#
#   가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도
# 0      70세         경상       승용        여      50세       상해없음
# 1      20세         중상       승용        여      42세       상해없음
# 2      75세         경상       승용        남      81세       상해없음
# 3      76세       부상신고       승용        남      75세       상해없음
# 4      61세         경상       화물        남      29세       상해없음
#
# [5 rows x 22 columns]

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31198 entries, 0 to 32631
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        31198 non-null  int64
#  1   사고일시        31198 non-null  object
#  2   요일          31198 non-null  object
#  3   시군구         31198 non-null  object
#  4   사고내용        31198 non-null  object
#  5   사망자수        31198 non-null  int64
#  6   중상자수        31198 non-null  int64
#  7   경상자수        31198 non-null  int64
#  8   부상신고자수      31198 non-null  int64
#  9   사고유형        31198 non-null  object
#  10  법규위반        31198 non-null  object
#  11  노면상태        31198 non-null  object
#  12  기상상태        31198 non-null  object
#  13  도로형태        31198 non-null  object
#  14  가해운전자 차종    31198 non-null  object
#  15  가해운전자 성별    31198 non-null  object
#  16  가해운전자 연령    31198 non-null  object
#  17  가해운전자 상해정도  31198 non-null  object
#  18  피해운전자 차종    31198 non-null  object
#  19  피해운전자 성별    31198 non-null  object
#  20  피해운전자 연령    31198 non-null  object
#  21  피해운전자 상해정도  31198 non-null  object
# dtypes: int64(5), object(17)
# memory usage: 5.5+ MB

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(f"칼럼 '{column}'의 유니크한 값: {unique_values}")
    print()
# Out:
# 칼럼 '사고번호'의 유니크한 값: [2020010200100362 2020010800100465 2020011000100216 ... 2019121400100366
#  2019122100100277 2019123000100415]
#
# 칼럼 '사고일시'의 유니크한 값: ['2020년 1월 2일 17시' '2020년 1월 8일 18시' '2020년 1월 10일 11시' ...
#  '2019년 12월 7일 13시' '2019년 12월 10일 06시' '2019년 12월 14일 12시']
#
# 칼럼 '요일'의 유니크한 값: ['목요일' '수요일' '금요일' '토요일' '월요일' '화요일' '일요일']
#
# 칼럼 '시군구'의 유니크한 값: ['경상북도 포항시 북구 죽도동' '경상북도 경주시 안강읍' '경상북도 안동시 운흥동' ... '대전광역시 유성구 계산동'
#  '대전광역시 유성구 용계동' '대전광역시 동구 신하동']
#
# 칼럼 '사고내용'의 유니크한 값: ['경상사고' '중상사고' '부상신고사고' '사망사고']
#
# 칼럼 '사망자수'의 유니크한 값: [0 1]
#
# 칼럼 '중상자수'의 유니크한 값: [0 1 2 3]
#
# 칼럼 '경상자수'의 유니크한 값: [ 1  0  2  4  3  5  7  6 10]
#
# 칼럼 '부상신고자수'의 유니크한 값: [0 1 2 3 4 6 5]
#
# 칼럼 '사고유형'의 유니크한 값: ['차대차 - 측면충돌' '차대차 - 정면충돌' '차대차 - 기타' '차대사람 - 차도통행중' '차대차 - 추돌'
#  '차대사람 - 길가장자리구역통행중' '차대사람 - 기타' '차대사람 - 보도통행중' '차대사람 - 횡단중' '차량단독 - 전도전복'
#  '차량단독 - 전도전복 - 전도' '차대차 - 후진중충돌' '차량단독 - 전도전복 - 전복' '철길건널목 - 철길건널목']
#
# 칼럼 '법규위반'의 유니크한 값: ['교차로운행방법위반' '안전운전불이행' '중앙선침범' '신호위반' '차로위반' '직진우회전진행방해' '안전거리미확보' '기타'
#  '보행자보호의무위반' '불법유턴']
#
# 칼럼 '노면상태'의 유니크한 값: ['건조' '젖음/습기' '기타' '서리/결빙' '적설' '침수']
#
# 칼럼 '기상상태'의 유니크한 값: ['맑음' '비' '흐림' '기타' '안개' '눈']
#
# 칼럼 '도로형태'의 유니크한 값: ['교차로 - 교차로안' '단일로 - 기타' '교차로 - 교차로부근' '기타 - 기타' '단일로 - 지하차도(도로)내'
#  '교차로 - 교차로횡단보도내' '주차장 - 주차장' '단일로 - 교량' '단일로 - 고가도로위' '단일로 - 터널'
#  '미분류 - 미분류' '단일로 - 철길건널목']
#
# 칼럼 '가해운전자 차종'의 유니크한 값: ['자전거']
#
# 칼럼 '가해운전자 성별'의 유니크한 값: ['남' '여' '기타불명']
#
# 칼럼 '가해운전자 연령'의 유니크한 값: ['70세' '20세' '75세' '76세' '61세' '84세' '59세' '19세' '67세' '11세' '64세' '80세'
#  '79세' '72세' '66세' '18세' '15세' '85세' '63세' '73세' '57세' '81세' '45세' '60세'
#  '65세' '39세' '54세' '56세' '22세' '51세' '77세' '미분류' '53세' '46세' '78세' '25세'
#  '68세' '74세' '52세' '36세' '28세' '47세' '69세' '43세' '55세' '31세' '8세' '71세'
#  '82세' '10세' '6세' '17세' '30세' '9세' '37세' '12세' '38세' '13세' '62세' '58세'
#  '14세' '44세' '42세' '27세' '49세' '98세 이상' '40세' '26세' '29세' '7세' '16세' '89세'
#  '86세' '41세' '83세' '23세' '48세' '24세' '33세' '50세' '88세' '96세' '21세' '87세'
#  '91세' '35세' '34세' '92세' '90세 이상' '1세' '32세' '97세' '90세' '5세' '93세' '94세'
#  '95세' '4세']
#
# 칼럼 '가해운전자 상해정도'의 유니크한 값: ['경상' '중상' '부상신고' '상해없음' '기타불명' '사망']
#
# 칼럼 '피해운전자 차종'의 유니크한 값: ['승용' '화물' '이륜' '승합' '보행자' '자전거' '건설기계' '기타불명' '원동기' '특수' '개인형이동수단(PM)'
#  '미분류' '사륜오토바이(ATV)' '농기계']
#
# 칼럼 '피해운전자 성별'의 유니크한 값: ['여' '남' '기타불명' '미분류']
#
# 칼럼 '피해운전자 연령'의 유니크한 값: ['50세' '42세' '81세' '75세' '29세' '45세' '53세' '44세' '36세' '76세' '64세' '32세'
#  '33세' '37세' '74세' '38세' '20세' '52세' '80세' '67세' '47세' '43세' '57세' '62세'
#  '73세' '49세' '58세' '39세' '46세' '61세' '56세' '77세' '3세' '63세' '51세' '69세'
#  '48세' '30세' '55세' '71세' '31세' '54세' '24세' '59세' '28세' '79세' '41세' '68세'
#  '60세' '14세' '65세' '25세' '66세' '27세' '35세' '16세' '23세' '미분류' '26세' '40세'
#  '10세' '70세' '6세' '5세' '34세' '8세' '72세' '15세' '19세' '82세' '7세' '78세' '21세'
#  '87세' '9세' '83세' '84세' '22세' '11세' '4세' '17세' '85세' '18세' '13세' '12세'
#  '1세' '90세' '86세' '91세' '2세' '90세 이상' '89세' '88세' '92세' '94세' '기타불명' '97세'
#  '93세']
#
# 칼럼 '피해운전자 상해정도'의 유니크한 값: ['상해없음' '기타불명' '부상신고' '경상' '중상' '사망' '미분류']

# %%
value_to_drop = ['미분류', '기타불명']
column_to_check = ['가해운전자 연령','피해운전자 연령','피해운전자 차종','피해운전자 성별', '가해운전자 성별']

# Create a boolean mask for rows with the specified value in the specified column
mask = df[column_to_check].isin(value_to_drop).any(axis=1)

# Drop rows based on the mask
df = df[~mask]

# If you want to reset the index after dropping rows
df.reset_index(drop=True, inplace=True)

# %%
df['가해운전자 연령'] = df['가해운전자 연령'].str.extract('(\d+)').astype(int)
df['피해운전자 연령'] = df['피해운전자 연령'].str.extract('(\d+)').astype(int)

# %%
for column in df.columns:
    unique_values = df[column].unique()
    print(f"칼럼 '{column}'의 유니크한 값: {unique_values}")
    print()
# Out:
# 칼럼 '사고번호'의 유니크한 값: [2020010200100362 2020010800100465 2020011000100216 ... 2019121400100366
#  2019122100100277 2019123000100415]
#
# 칼럼 '사고일시'의 유니크한 값: ['2020년 1월 2일 17시' '2020년 1월 8일 18시' '2020년 1월 10일 11시' ...
#  '2019년 12월 7일 13시' '2019년 12월 10일 06시' '2019년 12월 14일 12시']
#
# 칼럼 '요일'의 유니크한 값: ['목요일' '수요일' '금요일' '토요일' '월요일' '화요일' '일요일']
#
# 칼럼 '시군구'의 유니크한 값: ['경상북도 포항시 북구 죽도동' '경상북도 경주시 안강읍' '경상북도 안동시 운흥동' ... '대전광역시 유성구 계산동'
#  '대전광역시 유성구 용계동' '대전광역시 동구 신하동']
#
# 칼럼 '사고내용'의 유니크한 값: ['경상사고' '중상사고' '부상신고사고' '사망사고']
#
# 칼럼 '사망자수'의 유니크한 값: [0 1]
#
# 칼럼 '중상자수'의 유니크한 값: [0 1 2 3]
#
# 칼럼 '경상자수'의 유니크한 값: [ 1  0  2  4  3  5  7  6 10]
#
# 칼럼 '부상신고자수'의 유니크한 값: [0 1 2 3 4 6 5]
#
# 칼럼 '사고유형'의 유니크한 값: ['차대차 - 측면충돌' '차대차 - 정면충돌' '차대차 - 기타' '차대사람 - 차도통행중' '차대차 - 추돌'
#  '차대사람 - 길가장자리구역통행중' '차대사람 - 기타' '차대사람 - 보도통행중' '차대사람 - 횡단중' '차대차 - 후진중충돌']
#
# 칼럼 '법규위반'의 유니크한 값: ['교차로운행방법위반' '안전운전불이행' '중앙선침범' '신호위반' '차로위반' '직진우회전진행방해' '안전거리미확보' '기타'
#  '보행자보호의무위반' '불법유턴']
#
# 칼럼 '노면상태'의 유니크한 값: ['건조' '젖음/습기' '기타' '적설' '서리/결빙' '침수']
#
# 칼럼 '기상상태'의 유니크한 값: ['맑음' '비' '흐림' '기타' '눈' '안개']
#
# 칼럼 '도로형태'의 유니크한 값: ['교차로 - 교차로안' '단일로 - 기타' '교차로 - 교차로부근' '기타 - 기타' '단일로 - 지하차도(도로)내'
#  '교차로 - 교차로횡단보도내' '주차장 - 주차장' '단일로 - 교량' '단일로 - 고가도로위' '단일로 - 터널'
#  '미분류 - 미분류']
#
# 칼럼 '가해운전자 차종'의 유니크한 값: ['자전거']
#
# 칼럼 '가해운전자 성별'의 유니크한 값: ['남' '여']
#
# 칼럼 '가해운전자 연령'의 유니크한 값: [70 20 75 76 61 84 59 19 67 11 64 80 79 72 66 18 15 85 63 73 57 81 45 60
#  65 39 54 56 22 51 77 53 46 78 25 68 74 52 36 28 47 69 43 55 31  8 71 82
#  10  6 17 30  9 37 12 38 13 62 58 14 44 42 27 49 98 40 26 29  7 16 89 86
#  41 83 23 48 24 33 50 88 96 21 87 91 35 34 92 90  1 32 97  5 93 94 95  4]
#
# 칼럼 '가해운전자 상해정도'의 유니크한 값: ['경상' '중상' '부상신고' '상해없음' '기타불명' '사망']
#
# 칼럼 '피해운전자 차종'의 유니크한 값: ['승용' '화물' '이륜' '승합' '보행자' '자전거' '건설기계' '원동기' '특수' '개인형이동수단(PM)'
#  '사륜오토바이(ATV)' '농기계']
#
# 칼럼 '피해운전자 성별'의 유니크한 값: ['여' '남']
#
# 칼럼 '피해운전자 연령'의 유니크한 값: [50 42 81 75 29 45 53 44 36 76 64 32 33 37 74 38 20 52 80 67 47 43 57 62
#  73 49 58 39 46 61 56 77  3 63 51 69 48 30 55 71 31 54 24 59 28 79 41 68
#  60 14 65 25 66 27 35 16 23 26 40 10 70  6  5 34  8 72 15 19 82  7 78 21
#  87  9 83 84 22 11  4 85 18 13 12 17  1 90 86 91  2 89 88 92 94 97 93]
#
# 칼럼 '피해운전자 상해정도'의 유니크한 값: ['상해없음' '기타불명' '부상신고' '경상' '중상' '사망']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30373 entries, 0 to 30372
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        30373 non-null  int64
#  1   사고일시        30373 non-null  object
#  2   요일          30373 non-null  object
#  3   시군구         30373 non-null  object
#  4   사고내용        30373 non-null  object
#  5   사망자수        30373 non-null  int64
#  6   중상자수        30373 non-null  int64
#  7   경상자수        30373 non-null  int64
#  8   부상신고자수      30373 non-null  int64
#  9   사고유형        30373 non-null  object
#  10  법규위반        30373 non-null  object
#  11  노면상태        30373 non-null  object
#  12  기상상태        30373 non-null  object
#  13  도로형태        30373 non-null  object
#  14  가해운전자 차종    30373 non-null  object
#  15  가해운전자 성별    30373 non-null  object
#  16  가해운전자 연령    30373 non-null  int64
#  17  가해운전자 상해정도  30373 non-null  object
#  18  피해운전자 차종    30373 non-null  object
#  19  피해운전자 성별    30373 non-null  object
#  20  피해운전자 연령    30373 non-null  int64
#  21  피해운전자 상해정도  30373 non-null  object
# dtypes: int64(7), object(15)
# memory usage: 5.1+ MB

# %%
df.to_csv('jung.csv', index=False)

# %%
# df['사망자수'].value_counts(normalize=True)

# %% [markdown]
# # 여기부터 시작입니다 시각화 시작하시면 됩니다.

# %% [markdown]
# # 교통사고 인적피해의 구분
# [출처](https://taas.koroad.or.kr/sta/acs/exs/wordArngPopup.do)
#
# - "사망" 이란 교통사고 발생시로부터 30일이내에 사망한 경우. (99년까지는 72시간 이내)
# - "중상" 이란 교통사고로 인하여 3주 이상의 치료를 요하는 부상을 입은 경우.
# - "경상" 이란 교통사고로 인하여 5일 이상 3주 미만의 치료를 요하는 부상을 입은 경우.
# - "부상신고" 란 교통사고로 인하여 5일 미만의 치료를 요하는 부상을 입은 경우.

# %%
df['가해운전자 상해정도'].value_counts()
# Out:
# 경상      10386
# 상해없음     8181
# 부상신고     5712
# 중상       5115
# 기타불명      639
# 사망        340
# Name: 가해운전자 상해정도, dtype: int64

# %%
df['damage_level'] = df['가해운전자 상해정도'].map({'경상': 1, '부상신고': 1, '기타불명': 0, '상해없음': 0, '사망': 2, '중상': 2})

# %%
df['damage_level'].value_counts()
# Out:
# 1    16098
# 0     8820
# 2     5455
# Name: damage_level, dtype: int64

# %% [markdown]
# # 널값
#
# 1. 가해운전자 성별
# 2. 가해운전 상해정도
# 3. 피해운전자 차종
# 4. 피해운전자 성별
# 5. 피해운전자 연령
# 6. 피해운전자 상해정도

# %%
df['피해운전자 상해정도'].value_counts()
# Out:
# 상해없음    19080
# 경상       6281
# 중상       3718
# 부상신고     1142
# 기타불명      802
# 미분류       144
# 사망         31
# Name: 피해운전자 상해정도, dtype: int64

# %%
df.isnull().sum()
# Out:
# 사고번호             0
# 사고일시             0
# 요일               0
# 시군구              0
# 사고내용             0
# 사망자수             0
# 중상자수             0
# 경상자수             0
# 부상신고자수           0
# 사고유형             0
# 법규위반             0
# 노면상태             0
# 기상상태             0
# 도로형태             0
# 가해운전자 차종         0
# 가해운전자 성별         0
# 가해운전자 연령         0
# 가해운전자 상해정도       0
# 피해운전자 차종      1434
# 피해운전자 성별      1434
# 피해운전자 연령      1434
# 피해운전자 상해정도    1434
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#                    사고번호               사고일시   요일              시군구    사고내용  \
# 16     2020020200100258    2020년 2월 2일 16시  일요일     경상북도 예천군 풍양면    중상사고
# 43     2020031300100304   2020년 3월 13일 16시  금요일     경상북도 영양군 일월면  부상신고사고
# 56     2020040200100305    2020년 4월 2일 14시  목요일  경상북도 포항시 남구 대송면    중상사고
# 62     2020041500100443   2020년 4월 15일 21시  수요일     경상북도 구미시 공단동    경상사고
# 70     2020042100100372   2020년 4월 21일 17시  화요일  경상북도 포항시 남구 일월동    경상사고
# ...                 ...                ...  ...              ...     ...
# 32574  2019090600100616    2019년 9월 6일 20시  금요일    대전광역시 유성구 구암동    경상사고
# 32583  2019092700100586   2019년 9월 27일 18시  금요일     대전광역시 중구 산성동  부상신고사고
# 32601  2019102100100248  2019년 10월 21일 10시  월요일    대전광역시 서구 가수원동    중상사고
# 32602  2019102200100350  2019년 10월 22일 13시  화요일     대전광역시 서구 탄방동    중상사고
# 32630  2019122500100354  2019년 12월 25일 18시  수요일     대전광역시 중구 유천동  부상신고사고
#
#        사망자수  중상자수  경상자수  부상신고자수               사고유형  ... 기상상태             도로형태  \
# 16        0     1     0       0   차량단독 - 전도전복 - 전도  ...   맑음         단일로 - 기타
# 43        0     0     0       1  차량단독 - 도로외이탈 - 추락  ...   맑음          기타 - 기타
# 56        0     1     0       0          차량단독 - 기타  ...   맑음         단일로 - 기타
# 62        0     0     1       0          차량단독 - 기타  ...   맑음         단일로 - 기타
# 70        0     0     1       0          차량단독 - 기타  ...   맑음      교차로 - 교차로부근
# ...     ...   ...   ...     ...                ...  ...  ...              ...
# 32574     0     0     1       0   차량단독 - 주/정차차량 충돌  ...   맑음         단일로 - 기타
# 32583     0     0     0       1          차량단독 - 기타  ...   맑음  단일로 - 지하차도(도로)내
# 32601     0     1     0       0          차량단독 - 기타  ...   맑음         단일로 - 기타
# 32602     0     1     0       0   차량단독 - 전도전복 - 전도  ...   맑음       교차로 - 교차로안
# 32630     0     0     0       1       차량단독 - 공작물충돌  ...   맑음          기타 - 기타
#
#       가해운전자 차종 가해운전자 성별 가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령  \
# 16         자전거        남      72세         중상      NaN      NaN      NaN
# 43         자전거        남      81세       부상신고      NaN      NaN      NaN
# 56         자전거        남      67세         중상      NaN      NaN      NaN
# 62         자전거        남      53세         경상      NaN      NaN      NaN
# 70         자전거        남      38세         경상      NaN      NaN      NaN
# ...        ...      ...      ...        ...      ...      ...      ...
# 32574      자전거        남      68세         경상      NaN      NaN      NaN
# 32583      자전거        여      57세       부상신고      NaN      NaN      NaN
# 32601      자전거        여      41세         중상      NaN      NaN      NaN
# 32602      자전거        남      30세         중상      NaN      NaN      NaN
# 32630      자전거        남      60세       부상신고      NaN      NaN      NaN
#
#       피해운전자 상해정도
# 16           NaN
# 43           NaN
# 56           NaN
# 62           NaN
# 70           NaN
# ...          ...
# 32574        NaN
# 32583        NaN
# 32601        NaN
# 32602        NaN
# 32630        NaN
#
# [1434 rows x 22 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31198 entries, 0 to 32631
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고번호        31198 non-null  int64
#  1   사고일시        31198 non-null  object
#  2   요일          31198 non-null  object
#  3   시군구         31198 non-null  object
#  4   사고내용        31198 non-null  object
#  5   사망자수        31198 non-null  int64
#  6   중상자수        31198 non-null  int64
#  7   경상자수        31198 non-null  int64
#  8   부상신고자수      31198 non-null  int64
#  9   사고유형        31198 non-null  object
#  10  법규위반        31198 non-null  object
#  11  노면상태        31198 non-null  object
#  12  기상상태        31198 non-null  object
#  13  도로형태        31198 non-null  object
#  14  가해운전자 차종    31198 non-null  object
#  15  가해운전자 성별    31198 non-null  object
#  16  가해운전자 연령    31198 non-null  object
#  17  가해운전자 상해정도  31198 non-null  object
#  18  피해운전자 차종    31198 non-null  object
#  19  피해운전자 성별    31198 non-null  object
#  20  피해운전자 연령    31198 non-null  object
#  21  피해운전자 상해정도  31198 non-null  object
# dtypes: int64(5), object(17)
# memory usage: 5.5+ MB

# %%
day_order = ['월요일', '화요일', '수요일', '목요일', '금요일', '토요일', '일요일']
plt.figure(figsize=(10,6))
sns.countplot(x='요일',order=day_order, data=df )
plt.title('요일별 사고 발생 횟수')
plt.show()
